# %% [markdown]
# <div align="center">
#
# # Mortgage Risk Modeling
# # 4.0 Feature Engineering

# %% [markdown]
# ## 4.1 Table of Contents<a id='4.1_Table_of_Contents'></a>
# * [4.1 Table of Contents](#4.1_Table_of_Contents)
# * [4.2 Introduction](#4.2_Introduction)
# * [4.3 Library Imports](#4.3_Library_Imports)
# * [4.4 Data Loading](#4.4_Data_Loading)
# * [4.5 Feature Engineering](#4.5_Feature_Engineering)
#     * [4.5.1 MI Flag](#4.5.1_MI_Flag)
#     * [4.5.2 Term in Years](#4.5.2_Term_in_Years)
#     * [4.5.3 DTI and LTV Features](#4.5.3_DTI_and_LTV_Features)
#     * [4.5.4 DTI and UPB Features](#4.5.4_DTI_and_UPB_Features)
# * [4.6 Data Transformation & Splitting](#4.6_Data_Transformation_and_Splitting)
# * [4.7 Summary](#4.7_Summary)

# %% [markdown]
# ## 4.2 Introduction<a id='4.2_Introduction'></a>

# %% [markdown]
# In this section, we engineer additional features to improve model performance. We create binary indicators and composite metrics from existing variables, including the mortgage insurance (MI) flag, loan term in years, home value and its logarithm, and various interactions combining debt-to-income (DTI), loan-to-value (LTV), and original unpaid balance (UPB). These engineered features capture important relationships between borrower risk factors and the loan characteristics.

# %% [markdown]
# ## 4.3 Library Imports<a id='4.3_Library_Imports'></a>

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# Scikit-learn preprocessing tools
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

# For saving/loading processed data/models
from joblib import dump

# Optional: warnings filter (useful for cleaner output)
import warnings
warnings.filterwarnings("ignore")

# Set a consistent random state for reproducibility
RANDOM_STATE = 17
np.random.seed(RANDOM_STATE)

# %% [markdown]
# ## 4.4 Data Loading<a id='4.4_Data_Loading'></a>

# %%
# Load analyzed data from previous step
df = pd.read_csv("../data/processed/mrm_data_02_analyzed.csv")

print(f"Shape of df: {df.shape}")
df.head()
# Out:
# Shape of df: (104871, 26)
#     LOAN_ID  ACT_PERIOD CHANNEL  ORIG_RATE  ORIG_UPB  ORIG_TERM   ORIG_DATE  \
# 0  98836742  2020-01-01       C      3.375  308000.0        180  2019-08-01
# 1  98836743  2020-01-01       R      3.625  207000.0        240  2019-12-01
# 2  98836744  2020-01-01       R      3.625  215000.0        240  2020-01-01
# 3  98836781  2020-01-01       R      3.750  286000.0        360  2020-01-01
# 4  98836789  2020-01-01       R      3.990  222000.0        360  2019-12-01
#
#     FIRST_PAY  OLTV  NUM_BO  ...  OCC_STAT  STATE    MSA MI_TYPE  \
# 0  2019-10-01    75       1  ...         P     MI  19820     0.0
# 1  2020-02-01    66       2  ...         P     OH  17140     0.0
# 2  2020-03-01    73       2  ...         P     OH  18140     0.0
# 3  2020-03-01    79       2  ...         P     CO  17820     0.0
# 4  2020-02-01    78       2  ...         P     MI  19820     0.0
#
#   HOMEREADY_PROGRAM_INDICATOR  RELOCATION_MORTGAGE_INDICATOR  \
# ...

# %%
# Calculate the overall portfolio rates
default_rate = df['DEFAULT_FLAG'].mean() * 100
prepaid_rate = df['PREPAID_FLAG'].mean() * 100

print(f"Overall Default Rate: {default_rate:.2f}%")
print(f"Overall Prepaid Rate: {prepaid_rate:.2f}%")
# Out:
# Overall Default Rate: 2.35%
# Overall Prepaid Rate: 50.89%

# %% [markdown]
# ## 4.5 Feature Engineering<a id='4.5_Feature_Engineering'></a>

# %% [markdown]
# ### 4.5.1 MI Flag<a id='4.5.1_MI_Flag'></a>
#
# Based on the EDA, `MI_TYPE` contains four groups, but more than 99% of the observations fall into groups 0 and 1. The smaller groups, 2 and 3, do not show meaningful differences in default or prepayment rates. Therefore, groups 2 and 3 are merged into group 1 to indicate that the loan has mortgage insurance, while group 0 indicates no mortgage insurance. This simplifies `MI_TYPE` into a binary feature.

# %%
# Create MI flag: 0 if MI_TYPE == 0, else 1
df['MI'] = np.where(df['MI_TYPE'] == 0, 0, 1)

# Drop the categorical MI_TYPE now that we have the binary flag
df.drop(columns=['MI_TYPE'], inplace=True)

# Count distribution
mi_count = df['MI'].value_counts().sort_index()

# Percentage distribution
mi_pct = df['MI'].value_counts(normalize=True).sort_index() * 100

# Combine into one table
mi_summary = pd.DataFrame({
    'Count': mi_count,
    'Percentage (%)': mi_pct
})

print(mi_summary)
# Out:
#     Count  Percentage (%)
# MI
# 0   75225       71.730984
# 1   29646       28.269016

# %% [markdown]
# ### 4.5.2 Term in Years<a id='4.5.2_Term_in_Years'></a>
#
# Loan term, `ORIG_TERM`, is grouped into `15y`, `30y`, and `other` because 15‑year and 30‑year mortgages are the two standard loan products in the U.S. mortgage market. A 30‑year loan usually offers lower monthly payments but higher total interest cost, while a 15‑year loan usually has higher monthly payments but faster repayment and lower total interest. Since these two terms dominate the portfolio and carry clear business meaning, they are kept as separate categories, while all less common terms are grouped into “other.”

# %%
# Define 'TERM' column: 180 = 15y, 360 = 30y, rest = other
conditions = [
    (df['ORIG_TERM'] == 180),
    (df['ORIG_TERM'] == 360)
]

choices = ['15y', '30y']

# Create the column, defaulting everything else to 'other'
df['TERM'] = np.select(conditions, choices, default='other')

# Drop ORIG_TERM
df.drop(columns=['ORIG_TERM'], inplace=True)

# Count distribution
term_count = df['TERM'].value_counts()

# Percentage distribution
term_pct = df['TERM'].value_counts(normalize=True) * 100

# Combine into one table
term_summary = pd.DataFrame({
    'Count': term_count,
    'Percentage (%)': term_pct
})

print(term_summary)
# Out:
#        Count  Percentage (%)
# TERM
# 30y    77816       74.201638
# 15y    15535       14.813437
# other  11520       10.984924

# %% [markdown]
# ### 4.5.3 DTI and LTV Features<a id='4.5.3_DTI_and_LTV_Features'></a>
#
# This feature is created by dividing the debt‑to‑income ratio (DTI) by the original loan‑to‑value ratio (OLTV) to capture the relationship between borrower repayment capacity and property leverage in a single variable. DTI reflects the borrower’s monthly debt burden relative to income, while OLTV represents the loan amount relative to the property value. By combining them as DTI / OLTV, this new feature provides an additional view of how borrower affordability compares with collateral leverage. This transformation may help the model detect patterns that are not fully captured when DTI and OLTV are used separately, especially if the interaction between income pressure and loan leverage influences default or prepayment behavior.

# %%
# DTI divided by OLTV
df['DTI_LTV'] = df['DTI'] / df['OLTV']

# Distribution plot for DTI_LTV
plt.figure(figsize=(10, 6))
sns.histplot(df['DTI_LTV'], bins=50, kde=True)

plt.title('Distribution of DTI_LTV', fontsize=14, fontweight='bold')
plt.xlabel('DTI / OLTV')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.5.4 DTI and UPB Features<a id='4.5.4_DTI_and_UPB_Features'></a>
#
# This feature is created by dividing the debt‑to‑income ratio (DTI) by the original unpaid balance (ORIG_UPB) to measure the borrower’s debt burden relative to the size of the loan. DTI reflects the borrower’s monthly financial obligation compared with income, while ORIG_UPB represents the original loan amount. By combining them as DTI / ORIG_UPB, this feature provides a scaled view of borrower affordability in relation to loan size. It may help the model identify whether a given level of debt burden has a different risk implication for smaller versus larger loans, adding information beyond the two variables when used separately.

# %%
# Create DTI_UPB first
df['DTI_UPB'] = df['DTI'] / df['ORIG_UPB']

# Clean values for plotting
dti_upb_plot = df['DTI_UPB'].replace([np.inf, -np.inf], np.nan).dropna()

# Trim extreme values for visualization only
upper_limit = dti_upb_plot.quantile(0.99)

plt.figure(figsize=(10, 6))
sns.histplot(dti_upb_plot[dti_upb_plot <= upper_limit], bins=50, kde=True)

plt.title('Distribution of DTI_UPB (Trimmed at 99th Percentile)', fontsize=14, fontweight='bold')
plt.xlabel('DTI / ORIG_UPB')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4.6 Data Transformation & Splitting<a id='4.6_Data_Transformation_and_Splitting'></a>

# %%
# Standardize binary categorical flags to 0/1 for modeling consistency
binary_map = {'N': 0, 'Y': 1}

binary_cols = [
    'FIRST_FLAG',
    'HOMEREADY_PROGRAM_INDICATOR',
    'RELOCATION_MORTGAGE_INDICATOR',
    'PROPERTY_INSPECTION_WAIVER_INDICATOR',
    'HIGH_BALANCE_LOAN_INDICATOR'
]

for col in binary_cols:
    df[col] = df[col].replace(binary_map)

# %%
# Create X and Y for default model and repayment model
# Categorical features
cat_cols = [
    'CHANNEL',   # Loan origination channel
    'FIRST_FLAG',   # First-time homebuyer indicator
    'PURPOSE',   # Loan purpose
    'PROP',   # Property type
    'OCC_STAT',   # Occupancy status
    'STATE',   # Property state
    'MSA',   # Metropolitan Statistical Area
    'HOMEREADY_PROGRAM_INDICATOR',   # HomeReady participation indicator
    'RELOCATION_MORTGAGE_INDICATOR',   # Relocation mortgage indicator
    'PROPERTY_INSPECTION_WAIVER_INDICATOR',   # Property inspection waiver indicator
    'HIGH_BALANCE_LOAN_INDICATOR',   # High-balance loan indicator
    'MI',   # Binary mortgage insurance flag
    'TERM'   # Simplified loan term category
]

# Numerical features
num_cols = [
    'CSCORE_B',   # Borrower credit score, measuring the applicant’s credit quality
    'DTI',   # Debt-to-income ratio, reflecting the borrower’s repayment burden
    'OLTV',   # Original loan-to-value ratio, representing the loan amount relative to property value
    'ORIG_RATE',   # Original interest rate
    'ORIG_UPB',   # Original unpaid principal balance
    'NUM_BO',   # Number of borrowers
    'NO_UNITS',   # Number of property units
    'DTI_LTV',   # DTI divided by OLTV
    'DTI_UPB'   # DTI divided by ORIG_UPB
]

# Filter final dataset
df_model = df[cat_cols + num_cols + ['DEFAULT_FLAG', 'PREPAID_FLAG']].copy()

# Define X and y
X = df_model[cat_cols + num_cols]
y_default = df_model['DEFAULT_FLAG']
y_prepaid = df_model['PREPAID_FLAG']

print(X.shape)
print(y_default.shape)
print(y_prepaid.shape)
# Out:
# (104871, 22)
# (104871,)
# (104871,)

# %%
# Split X and both targets using the same row split
X_train, X_test, y_default_train, y_default_test = train_test_split(
    X,
    y_default,
    test_size=0.2,
    random_state=17,
    stratify=y_default
)

# Align prepaid target to the same split
y_prepaid_train = y_prepaid.loc[X_train.index]
y_prepaid_test = y_prepaid.loc[X_test.index]

print(X_train.shape)
print(X_test.shape)
print(y_default_train.shape)
print(y_default_test.shape)
print(y_prepaid_train.shape)
print(y_prepaid_test.shape)
# Out:
# (83896, 22)
# (20975, 22)
# (83896,)
# (20975,)
# (83896,)
# (20975,)

# %%
print(f'Overall default rate: {y_default.mean():.2%}')
print(f'Train default rate: {y_default_train.mean():.2%}')
print(f'Test default rate: {y_default_test.mean():.2%}')

print(f'Overall prepaid rate: {y_prepaid.mean():.2%}')
print(f'Train prepaid rate: {y_prepaid_train.mean():.2%}')
print(f'Test prepaid rate: {y_prepaid_test.mean():.2%}')
# Out:
# Overall default rate: 2.35%
# Train default rate: 2.35%
# Test default rate: 2.36%
# Overall prepaid rate: 50.89%
# Train prepaid rate: 50.92%
# Test prepaid rate: 50.78%

# %%
# Creat a feature transformer
transformer = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_cols)
    ]
)

X_train_transformed = transformer.fit_transform(X_train)
X_test_transformed = transformer.transform(X_test)

print(X_train_transformed.shape)
print(X_test_transformed.shape)
# Out:
# (83896, 107)
# (20975, 107)

# %% [markdown]
# ## 4.7 Summary<a id='4.7_Summary'></a>

# %% [markdown]
# In this stage, the cleaned mortgage dataset was prepared for modeling by simplifying features and creating new variables with clearer business meaning. MI_TYPE was converted into a binary MI flag, and ORIG_TERM was grouped into 15y, 30y, and other to reflect the most common loan terms in the mortgage market.
#
# Two interaction features were also created: DTI_LTV, which measures debt burden relative to property leverage, and DTI_UPB, which measures debt burden relative to loan size. These features help capture relationships that may not be fully reflected by the original variables alone.
#
# After feature creation, the final modeling features were selected and separated into categorical and numerical groups. The dataset was then split into training and testing sets, with the default rate kept close to the overall portfolio average through stratified sampling. Finally, numerical features were scaled and categorical features were one-hot encoded using a transformer fitted only on the training set to avoid data leakage.

# %%
# Save processed data and assets for modeling
save_path = '../data/processed'
model_path = '../models'

os.makedirs(save_path, exist_ok=True)
os.makedirs(model_path, exist_ok=True)

# Save featured data
df.to_csv("../data/processed/data_03_featured.csv", index=False)

# Save raw split features
X_train.to_csv(f'{save_path}/X_train.csv', index=True)
X_test.to_csv(f'{save_path}/X_test.csv', index=True)

# Save targets
y_default_train.to_csv(f'{save_path}/y_default_train.csv', index=True)
y_default_test.to_csv(f'{save_path}/y_default_test.csv', index=True)

y_prepaid_train.to_csv(f'{save_path}/y_prepaid_train.csv', index=True)
y_prepaid_test.to_csv(f'{save_path}/y_prepaid_test.csv', index=True)

# Save fitted transformer
joblib.dump(transformer, f'{model_path}/feature_transformer.pkl')

print('Raw split datasets and transformer saved successfully.')
# Out:
# Raw split datasets and transformer saved successfully.
